# %%
# request import
import requests as rq

# BSoup imports
import urllib.request
from bs4 import BeautifulSoup as BSoup

# Selenium imports
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select

# Pandas imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Utils import
import os
import random
import collections
import string
import time

# %%
DATA_FILE = './DataMeteo/StationInformation.csv'
FILTER_URL = 'http://www.infoclimat.fr/observations-meteo/temps-reel/lausanne/06710.html'
LATITUDE = 'lattitude'
LONGITUDE = 'longitude'
ALTITUDE = 'altitude (m)'
CURRENT_ADRESS = 'current_adress'
STATION = 'stationCity'

# %% [markdown]
# Get the different value for all the selection.

# %%
filters_page = rq.get(FILTER_URL) # Retrieving content of online form
filters = BSoup(filters_page.text, 'html.parser')

selects = filters.find('select',{'id': 'select_station'}) # Filter to get all stations
availableStation = []

for option in selects.findAll('option'):
    if option.text != 'Changer de station...':
        availableStation.append(option.text)
        
len(availableStation)
print(availableStation)
# Out:
# ['Adelboden', 'Aigle', 'Alpnach', 'Altdorf', 'Altenrhein', 'Ascona', 'Bâle-Binningen', 'Bern/Belp (Berne)', 'Berne Liebefeld', 'Buchs-Suhr', 'Buochs', 'Buochs', 'BUOCHS', 'Changins', 'Chasseral', 'Chur-Ems', 'Cimetta', 'Comprovasco', 'Corvatsch', 'Disentis', 'Dübendorf', 'Emmen', 'Ernen', 'Evolene-Villaz', 'Fahy-Boncourt', 'Fionnay', 'Gemmi', 'Genève-Cointrin', 'Giswil', 'Goesgen', 'Grand Saint-Bernhard', 'Grenchen', 'Guetsch', 'Hoernli', 'Interlaken', 'Jungfraujoch', 'La Cure', 'La Dole', 'La Fouly', 'La Fretaz', 'Laegern', 'Laufenburg', 'Lausanne', 'Lausanne - Pully', 'Leibstadt', 'Les Eplatures', 'Leysin', 'Locarno Monti', 'Locarno-Magadino', 'Lugano', 'Lugano/Agno', 'Meiringen', 'Mettlen', 'Moleson', 'Montana', 'Mühleberg', 'Napf', 'Neuchatel', 'Payerne', 'Payerne/Metar', 'Piotta', 'Plaffeien', 'Robbia', 'Ruenenberg', 'Saentis', 'Saint Gallen', 'Saint Gallen-Altenrhein', 'Saint-Triphon', 'Samedan', 'San Bernardino', 'Savatan', 'Sion', 'SION (MIL)', 'St. Moritz', 'Stabio', 'Ulrichen', 'Versoix', 'Villarzel', 'Visp', 'Weesen', 'Wynau', 'Zermatt', 'Zurich SMA', 'Zürich/Kloten']

# %%
def getLatitude(valueListElement):
    temp = valueListElement.rsplit('\t',4)
    temp = temp[2].rsplit('|',1)
    temp = temp[0].replace(" ","")
    temp = temp.replace("Â°N","")
    temp = temp.replace(",",".")
    print ('lattitude is: '+temp )
    return temp

# %%
def getAltitude(valueListElement):
    temp = valueListElement.rsplit(' ',3)
    print ('altitude is: '+temp[1] )
    return temp[1]

# %%
def getLongitude(valueListElement):
    temp = valueListElement.rsplit('\t',4)
    temp = temp[2].rsplit('|',1)
    temp = temp[1].replace(" ","")
    temp = temp.replace("Â°E","")
    temp = temp.replace(",",".")
    print ('longitude is: '+ temp )
    return temp

# %%
getLongitude('\nCoordonnÃ©es\n\t\t    46,30Â°N | 7,34Â°E \t\t')
# Out:
# longitude is: 7.34
# '7.34'

# %%
def multiselect_set_selections(driver, element_id, labels):
    result = collections.defaultdict(list)
    
    # Select with the id and loop in oder to get all information about the station.
    for labelText in labels:
        
        #Selenium soup request.
        print ('request for : ' + labelText)
        select = WebDriverWait(driver, 10).until(lambda driver:Select(driver.find_element_by_id(element_id)))
        select.select_by_visible_text(labelText)
        
        #BeautifulSoup request.
        filters = BSoup(driver.page_source.encode('utf-8'), 'html.parser')
        selects = filters.find('ul',{'id': 'station-informations'}).findAll('li')
        
        #get the result.
        result[CURRENT_ADRESS].append(driver.current_url)
        result[LATITUDE].append((getLatitude(selects[1].get_text())))
        result[LONGITUDE].append((getLongitude(selects[1].get_text())))
        result[ALTITUDE].append(getAltitude(selects[0].get_text())) 
        
        # We have to wait to avoid the capcha.
        time.sleep(5)
              
    result[STATION] = availableStation
    return pd.DataFrame(data=result)

# %%
def getInformationStation():
    chromedriver = "./Utils/chromedriver"
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)
    driver.get(FILTER_URL)
    
    # get the result.
    result_screen_scraping = multiselect_set_selections(driver,'select_station',availableStation)
    result_screen_scraping.to_csv('example.csv')
    driver.close()

# %%
getInformationStation()
# Out:
# request for : Adelboden
# lattitude is: 46.30
# longitude is: 7.34
# altitude is: 1325
# request for : Aigle
# lattitude is: 46.33
# longitude is: 6.92
# altitude is: 383
# request for : Alpnach
# lattitude is: 45.93
# longitude is: 8.28
# altitude is: 445
# request for : Altdorf
# lattitude is: 46.87
# longitude is: 8.63
# altitude is: 449
# request for : Altenrhein
# lattitude is: 47.48
# longitude is: 9.57
# altitude is: 0
# request for : Ascona
# lattitude is: 46.15
# longitude is: 8.76
# altitude is: 196
# request for : Bâle-Binningen
# lattitude is: 47.55
# longitude is: 7.58
# altitude is: 316
# request for : Bern/Belp (Berne)
# lattitude is: 46.92
# longitude is: 7.50
# altitude is: 505
# request for : Berne Liebefeld
# lattitude is: 46.93
# longitude is: 7.42
# altitude is: 565
# request for : Buchs-Suhr
# lattitude is: 47.23
# longitude is: 8.05
# altitude is: 389
# request for : Buochs
# lattitude is: 46.98
# longitude is: 8.38
# altitude is: 0
# request for : Buochs
# lattitude is: 46.98
# longitude is: 8.38
# altitude is: 0
# request for : BUOCHS
# lattitude is: 46.98
# longitude is: 8.40
# altitude is: 444
# request for : Changins
# lattitude is: 46.24
# longitude is: 6.14
# altitude is: 432
# request for : Chasseral
# lattitude is: 47.08
# longitude is: 7.04
# altitude is: 1631
# request for : Chur-Ems
# lattitude is: 46.87
# longitude is: 9.53
# altitude is: 555
# request for : Cimetta
# lattitude is: 46.20
# longitude is: 8.80
# altitude is: 1672
# request for : Comprovasco
# lattitude is: 46.47
# longitude is: 8.93
# altitude is: 575
# request for : Corvatsch
# lattitude is: 46.42
# longitude is: 9.82
# altitude is: 3315
# request for : Disentis
# lattitude is: 46.70
# longitude is: 8.85
# altitude is: 1190
# request for : Dübendorf
# lattitude is: 46.55
# longitude is: 7.02
# altitude is: 1973
# request for : Emmen
# lattitude is: 47.10
# longitude is: 8.30
# altitude is: 427
# request for : Ernen
# lattitude is: 46.40
# longitude is: 8.13
# altitude is: 1000
# request for : Evolene-Villaz
# lattitude is: 46.07
# longitude is: 7.31
# altitude is: 1828
# request for : Fahy-Boncourt
# lattitude is: 47.42
# longitude is: 6.94
# altitude is: 597
# request for : Fionnay
# lattitude is: 46.03
# longitude is: 7.32
# altitude is: 1500
# request for : Gemmi
# lattitude is: 46.40
# longitude is: 7.62
# altitude is: 2342
# request for : Genève-Cointrin
# lattitude is: 46.23
# longitude is: 6.13
# altitude is: 405
# request for : Giswil
# lattitude is: 46.82
# longitude is: 8.17
# altitude is: 489
# request for : Goesgen
# lattitude is: 47.22
# longitude is: 7.59
# altitude is: 380
# request for : Grand Saint-Bernhard
# lattitude is: 45.87
# longitude is: 7.17
# altitude is: 2472
# request for : Grenchen
# lattitude is: 47.18
# longitude is: 7.42
# altitude is: 430
# request for : Guetsch
# lattitude is: 46.65
# longitude is: 8.62
# altitude is: 2284
# request for : Hoernli
# lattitude is: 47.37
# longitude is: 8.95
# altitude is: 1144
# request for : Interlaken
# lattitude is: 46.40
# longitude is: 7.52
# altitude is: 579
# request for : Jungfraujoch
# lattitude is: 46.55
# longitude is: 7.98
# altitude is: 3580
# request for : La Cure
# lattitude is: 46.47
# longitude is: 6.08
# altitude is: 1170
# request for : La Dole
# lattitude is: 46.43
# longitude is: 6.10
# altitude is: 1675
# request for : La Fouly
# lattitude is: 45.95
# longitude is: 7.11
# altitude is: 1509
# request for : La Fretaz
# lattitude is: 46.83
# longitude is: 6.58
# altitude is: 1210
# request for : Laegern
# lattitude is: 47.48
# longitude is: 8.40
# altitude is: 868
# request for : Laufenburg
# lattitude is: 47.55
# longitude is: 8.05
# altitude is: 322
# request for : Lausanne
# lattitude is: 46.55
# longitude is: 6.62
# altitude is: 616
# request for : Lausanne - Pully
# lattitude is: 46.52
# longitude is: 6.67
# altitude is: 462
# request for : Leibstadt
# lattitude is: 47.36
# longitude is: 8.11
# altitude is: 341
# request for : Les Eplatures
# lattitude is: 47.08
# longitude is: 6.79
# altitude is: 1027
# request for : Leysin
# lattitude is: 46.35
# longitude is: 7.03
# altitude is: 1360
# request for : Locarno Monti
# lattitude is: 46.17
# longitude is: 8.78
# altitude is: 366
# request for : Locarno-Magadino
# lattitude is: 46.17
# longitude is: 8.88
# altitude is: 197
# request for : Lugano
# lattitude is: 46.00
# longitude is: 8.97
# altitude is: 273
# request for : Lugano/Agno
# lattitude is: 46.00
# longitude is: 8.90
# altitude is: 279
# request for : Meiringen
# lattitude is: 46.75
# longitude is: 8.12
# altitude is: 579
# request for : Mettlen
# lattitude is: 47.12
# longitude is: 8.33
# altitude is: 417
# request for : Moleson
# lattitude is: 46.55
# longitude is: 7.02
# altitude is: 1973
# request for : Montana
# lattitude is: 46.19
# longitude is: 7.29
# altitude is: 1508
# request for : Mühleberg
# lattitude is: 46.97
# longitude is: 7.28
# altitude is: 482
# request for : Napf
# lattitude is: 47.00
# longitude is: 7.93
# altitude is: 1407
# request for : Neuchatel
# lattitude is: 46.96
# longitude is: 6.87
# altitude is: 487
# request for : Payerne
# lattitude is: 46.82
# longitude is: 6.94
# altitude is: 448
# request for : Payerne/Metar
# lattitude is: 46.82
# longitude is: 6.95
# altitude is: 491
# request for : Piotta
# lattitude is: 46.52
# longitude is: 8.68
# altitude is: 1007
# request for : Plaffeien
# lattitude is: 46.45
# longitude is: 7.16
# altitude is: 1041
# request for : Robbia
# lattitude is: 46.35
# longitude is: 10.07
# altitude is: 1078
# request for : Ruenenberg
# lattitude is: 47.26
# longitude is: 7.53
# altitude is: 610
# request for : Saentis
# lattitude is: 47.25
# longitude is: 9.35
# altitude is: 2490
# request for : Saint Gallen
# lattitude is: 47.43
# longitude is: 9.40
# altitude is: 779
# request for : Saint Gallen-Altenrhein
# lattitude is: 47.49
# longitude is: 9.56
# altitude is: 398
# request for : Saint-Triphon
# lattitude is: 46.29
# longitude is: 6.98
# altitude is: 441
# request for : Samedan
# lattitude is: 46.53
# longitude is: 9.88
# altitude is: 1706
# request for : San Bernardino
# lattitude is: 46.47
# longitude is: 9.18
# altitude is: 1639
# request for : Savatan
# lattitude is: 46.20
# longitude is: 7.02
# altitude is: 665
# request for : Sion
# lattitude is: 46.22
# longitude is: 7.33
# altitude is: 481
# request for : SION (MIL)
# lattitude is: 46.22
# longitude is: 7.33
# altitude is: 481
# request for : St. Moritz
# lattitude is: 46.50
# longitude is: 9.85
# altitude is: 1850
# request for : Stabio
# lattitude is: 45.85
# longitude is: 8.93
# altitude is: 353
# request for : Ulrichen
# lattitude is: 46.50
# longitude is: 8.32
# altitude is: 1348
# request for : Versoix
# lattitude is: 46.30
# longitude is: 6.17
# altitude is: 385
# request for : Villarzel
# lattitude is: 46.75
# longitude is: 6.91
# altitude is: 645
# request for : Visp
# lattitude is: 46.18
# longitude is: 7.51
# altitude is: 642
# request for : Weesen
# lattitude is: 47.13
# longitude is: 9.10
# altitude is: 423
# request for : Wynau
# lattitude is: 47.25
# longitude is: 7.78
# altitude is: 416
# request for : Zermatt
# lattitude is: 46.02
# longitude is: 7.45
# altitude is: 1621
# request for : Zurich SMA
# lattitude is: 47.38
# longitude is: 8.57
# altitude is: 556
# request for : Zürich/Kloten
# lattitude is: 47.48
# longitude is: 8.53
# altitude is: 432
